# %% [markdown]
# ## Importing the neccesaary dependencies

# %%
import math
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import numpy as np

import chart_studio.plotly as py
import plotly.graph_objs as go

# %%
# loading the dataset into pandas dataframe
tesla = pd.read_csv('TSLA.csv',parse_dates=['Date'],index_col= ['Date'],)

# %%
tesla.head()
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla.shape
# Out:
# (2416, 6)

# %%
# Visualizing the dataframe

lay = go.Layout(title="Close Price History", xaxis=dict(title="Date",titlefont=dict(family="Courier New, monospace", size=18,color="#7f7f7f")),
 yaxis=dict(title="Close Price",titlefont=dict(family="Courier New, monospace", size=18,color="#7f7f7f")))

tesla_data = [{'x':tesla['Date'],'y':tesla['Close']}]
plot = go.Figure(data=tesla_data, layout=lay)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
plot
# Out:
# <div>                            <div id="8bed2171-b409-478d-afc9-9ade435f9237" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bed2171-b409-478d-afc9-9ade435f9237")) {                    Plotly.newPlot(                        "8bed2171-b409-478d-afc9-9ade435f9237",                        [{"x":["2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00"
# ...

# %%
data = tesla.filter(['Close'])

# %%
data
# Out:
#                  Close
# Date
# 2010-06-29   23.889999
# 2010-06-30   23.830000
# 2010-07-01   21.959999
# 2010-07-02   19.200001
# 2010-07-06   16.110001
# ...                ...
# 2020-01-28  566.900024
# 2020-01-29  580.989990
# 2020-01-30  640.809998
# 2020-01-31  650.570007
# 2020-02-03  780.000000
#
# [2416 rows x 1 columns]

# %%
# converting the data into numpy array
con_data = data.values

# %%
con_data
# Out:
# array([[ 23.889999],
#        [ 23.83    ],
#        [ 21.959999],
#        ...,
#        [640.809998],
#        [650.570007],
#        [780.      ]])

# %%
train_con_data = math.ceil(len(con_data)* .8)
train_con_data
# Out:
# 1933

# %%
#Scaling the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(con_data)

scaled_data
# Out:
# array([[0.01058623],
#        [0.01050772],
#        [0.00806072],
#        ...,
#        [0.81786181],
#        [0.83063335],
#        [1.        ]])

# %%
train_data = scaled_data[0:train_con_data, :]

# %%
x_train = []
y_train = []

for i in range(60 , len(train_data)):
   
    x_train.append(train_data[i-60:i, 0]) 
    y_train.append(train_data[i, 0 ])
    
    if i<= 60:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.01058623, 0.01050772, 0.00806072, 0.0044491 , 0.00040565,
#        0.        , 0.0021722 , 0.00209369, 0.0016357 , 0.00306202,
#        0.00528657, 0.005352  , 0.00633342, 0.00799529, 0.00588851,
#        0.00578382, 0.0068045 , 0.00718398, 0.00673907, 0.00621565,
#        0.0064381 , 0.00595394, 0.00541743, 0.00669982, 0.00804763,
#        0.00714473, 0.0060848 , 0.00495943, 0.00497252, 0.00422664,
#        0.00274797, 0.0023554 , 0.00329757, 0.0038995 , 0.00438367,
#        0.00388642, 0.00391259, 0.00431824, 0.00566605, 0.0044491 ,
#        0.00536509, 0.0051688 , 0.00510338, 0.00532583, 0.00481549,
#        0.0060848 , 0.00688301, 0.00686993, 0.00620257, 0.00667365,
#        0.00642502, 0.0057184 , 0.0064381 , 0.00696153, 0.00808689,
#        0.00672599, 0.00579691, 0.00688301, 0.00650353, 0.00532583])]
# [0.004920176655325834]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train,(x_train.shape[0] , x_train.shape[1], 1))
x_train.shape
# Out:
# (1873, 60, 1)

# %% [markdown]
# ## Using LSTM model to make prediction

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences  = False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size = 1, epochs = 1)
# Out:
# 1873/1873 [==============================] - 69s 33ms/step - loss: 5.6826e-04

# %%
test_data = scaled_data[train_con_data - 60: , :]

# %%
x_test = []
y_test = con_data[train_con_data:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])

# %%
x_test = np.array(x_test)

# %%
x_test = np.reshape(x_test,(x_test.shape[0] , x_test.shape[1],1))

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 16/16 [==============================] - 2s 28ms/step

# %%
# Get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 3.9533240623038775

# %% [markdown]
# ## Visualizing the train data and predicted data

# %%
train = data[:train_con_data]
valid = data[train_con_data:]
valid['Predictions'] = predictions


plt.figure(figsize = (16,8))
plt.title('Prediction Model', fontsize = 19)
plt.xlabel('Year', fontsize = 21)
plt.ylabel('Close Price USD($)', fontsize = 19)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train','Test','Predictions'])
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6796\1108424807.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#visualizing the train data against the test data
plt.figure(figsize = (16,8))
plt.title('Train vs Test', fontsize = 19)
plt.xlabel('Year', fontsize = 21)
plt.ylabel('Close Price USD($)', fontsize = 19)
plt.plot(train['Close'])
plt.plot(valid[['Close']])
plt.legend(['Train','Test'])
plt.show()

# %%
#visualizing the test data against the predicted data
plt.figure(figsize = (12,6))
plt.title('Test vs Prediction', fontsize = 19)
plt.xlabel('Year', fontsize = 21)
plt.ylabel('Close Price USD($)', fontsize = 19)
plt.plot(valid['Close'])
plt.plot(valid[['Predictions']], color='g')
plt.legend(['Test','Predictions'])
plt.show()

# %%
# the close price against the predicted price
valid
# Out:
#                  Close  Predictions
# Date
# 2018-03-05  333.350006   348.117767
# 2018-03-06  328.200012   345.608185
# 2018-03-07  332.299988   342.676910
# 2018-03-08  329.100006   340.526825
# 2018-03-09  327.170013   338.645020
# ...                ...          ...
# 2020-01-28  566.900024   540.324707
# 2020-01-29  580.989990   543.879822
# 2020-01-30  640.809998   548.396179
# 2020-01-31  650.570007   561.280457
# 2020-02-03  780.000000   577.074402
#
# [483 rows x 2 columns]

# %%
print(f"The total number of data used to train is {train_con_data}")
print(f"The total number of data used for prediction is {len(valid)}")
print(" ")
print(f"Total: {train_con_data + len(valid)} ")
# Out:
# The total number of data used to train is 1933
# The total number of data used for prediction is 483
#
# Total: 2416
